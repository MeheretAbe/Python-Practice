# %% [markdown]
# ## Task 1
# Load the data into a Pandas DataFrame. Identify the number of rows and columns and check if there are any null values in the given data.

# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('DS1_C4_S3_Loan_Data_Challenge.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.shape
# Out:
# (614, 13)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    int64
#  9   Loan_Amount_Term   614 non-null    int64
#  10  Credit_History     614 non-null    int64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ## Task 2
# Display the list of female customers who are self-employed and have an income of more than $4,000.

# %%
F_Cus= data[(data.Gender=='Female')&(data.Self_Employed=='Yes')&(data.ApplicantIncome>4000)]
F_Cus
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# ## Task 3
# Identify those male customers who hold a graduate degree and have the loan status as 'Y' (yes).
#
# Display the information of these customers.
# Display the count of these customers.

# %%
M_Cus= data
[(data.Gender=='Male')&
(data.Education=='Graduate')&
(data.Loan_Status=='Y')]
M_Cus.count()
# Out:
# Loan_ID              614
# Gender               614
# Married              614
# Dependents           614
# Education            614
# Self_Employed        614
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           614
# Loan_Amount_Term     614
# Credit_History       614
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %% [markdown]
# ## Task 4
# Calculate the number of customers who have the loan status as 'Y', three or more dependents, and a property in a rural area. Display all the details of such customers.

# %%
L_Stat= data[(data.Dependents=='3+')&
(data.Property_Area=='Rural')&
(data.Loan_Status=='Y')]
L_Stat
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %% [markdown]
# ## Task 5
# A new customer, Warner Kim, has applied for a loan of $290,000. Warner Kim is a graduate and owns a property in an urban area. Check whether Warner Kim would get his loan approved or not.

# %%
W_Kim=data[(data.LoanAmount>=290000)&
(data.Education=='Graduate')&
(data.Property_Area=='Urban')&
(data.Loan_Status=='Y')]
W_Kim
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
W_Kim=data[(data.LoanAmount<=290000)&
(data.Education=='Graduate')&
(data.Property_Area=='Urban')&
(data.Loan_Status=='Y')]
W_Kim
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 594  LP002938   Male     Yes          0  Graduate           Yes
# 599  LP002948   Male     Yes          2  Graduate            No
# 602  LP002953   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %% [markdown]
# ## Task 6
# Identify the customers who are not married, are self-employed, live in a nonurban area, and have their loan status as 'N'.
# Calculate and display the gender-wise count of such customers.

# %%
N_Married_M=data[(data.Self_Employed=='Yes')&
(data.Property_Area=='Rural')&
(data.Loan_Status=='N')&
(data.Gender=='Male')&
(data.Married=='No')]
N_Married_M
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 32   LP001097   Male      No          1      Graduate           Yes
# 107  LP001370   Male      No          0  Not Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 32              4692                0.0         106               360
# 107             7333                0.0         120               360
#
#      Credit_History Property_Area Loan_Status
# 32                1         Rural           N
# 107               1         Rural           N

# %%
N_Married_F=data[(data.Self_Employed=='Yes')&
(data.Property_Area=='Rural')&
(data.Loan_Status=='N')&
(data.Gender=='Female')&
(data.Married=='No')]
N_Married_F
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 404  LP002301  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 404             7441                0.0         194               360
#
#      Credit_History Property_Area Loan_Status
# 404               1         Rural           N

# %% [markdown]
# ## Task 7
# Calculate and display the average income of customers based on each area where their property is located (urban, semiurban, rural).

# %%
Avg_inc_R = data[data['Property_Area']=='Rural']['ApplicantIncome'].mean()
Avg_inc_R
# Out:
# 5554.083798882682

# %%
Avg_inc_U= data[data['Property_Area']=='Urban']['ApplicantIncome'].mean()
Avg_inc_U
# Out:
# 5398.247524752475

# %%
Avg_inc_S= data[data['Property_Area']=='Semiurban']['ApplicantIncome'].mean()
Avg_inc_S
# Out:
# 5292.261802575107

# %% [markdown]
# ## Task 8
# List the customers who have a property in a rural or semiurban area, applicant's income > $4,000, coapplicant's income > $1,000, and loan status is 'N'. Count the number of such customers.
# Update the loan status of such customers to 'Y'.
# Redo the same task to verify that the count of such customers is now zero (after updating the loan status to 'Y').

# %%
Cu=data[(data.ApplicantIncome>4000)&
(data.Loan_Status=='N')&
(data.Property_Area!='Urban')&
(data.CoapplicantIncome>1000)]
Cu.count()
# Out:
# Loan_ID              23
# Gender               23
# Married              23
# Dependents           23
# Education            23
# Self_Employed        23
# ApplicantIncome      23
# CoapplicantIncome    23
# LoanAmount           23
# Loan_Amount_Term     23
# Credit_History       23
# Property_Area        23
# Loan_Status          23
# dtype: int64

# %%
# ony updating for the indexes that need update not the whole dataframe
Cu.index
# Out:
# Index([  1,   9,  34,  65,  83, 118, 129, 139, 140, 148, 177, 258, 298, 325,
#        351, 369, 499, 503, 514, 518, 524, 573, 585],
#       dtype='int64')

# %%
Cu.loc[Cu.index,Cu.Loan_Status] ='Y'
Cu
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %% [markdown]
# ## Task 9
# Display the average income and the count of customers who have 3+ dependents, live in an urban area, and have their loan status as 'Y'.

# %%
X= data[(data['Property_Area']=='Urban')&
(data['Dependents'] == '3+')&
(data['Loan_Status']=='Y')]['ApplicantIncome'].mean()
X
# Out:
# 11045.625

# %% [markdown]
# ## Task 10
# Display the list of customers who live in rural or semiurban areas with 3+ dependents and have an income that is more than the average income of the customers who live in an urban area
# What do you infer from this task? Can you infer an important parameter that the bank is using to approve loans?
# Display the average applicant income of those customers who are from nonurban areas and have their loan status as 'Y'.

# %%
#Customers with income that's more than the avg income of customers who live in an urban area
data[(data['Property_Area']!='Urban')&
(data['Dependents'] == '3+')&
(data['Loan_Status']=='Y')&
(data['ApplicantIncome']>X)]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 126  LP001448   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 324  LP002065   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 126            23803                0.0         370               360
# 155            39999                0.0         600               180
# 324            15000                0.0         300               360
#
#      Credit_History Property_Area Loan_Status
# 126               1         Rural           Y
# 155               0     Semiurban           Y
# 324               1         Rural           Y

# %%
#average applicant income of those customers who are from nonurban areas and have their loan status as 'Y'

A= data[(data['Property_Area']!='Urban')&
(data['Dependents'] == '3+')&
(data['Loan_Status']=='Y')]['ApplicantIncome'].mean()
A
# Out:
# 7861.28
